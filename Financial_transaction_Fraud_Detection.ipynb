# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, classification_report

# %%
df = pd.read_csv('fraud.csv')

# %%
df.head(2)
# Out:
#    Unnamed: 0           customerEmail   customerPhone        customerDevice  \
# 0           0  josephhoward@yahoo.com    400-108-5415  yyeiaxpltf82440jnb3v
# 1           1  evansjeffery@yahoo.com  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
#
#   customerIPAddress                             customerBillingAddress  \
# 0      8.129.104.40            5493 Jones Islands\nBrownside, CA 51896
# 1   219.173.211.202  356 Elizabeth Inlet Suite 120\nPort Joshuabury...
#
#    No_Transactions  No_Orders  No_Payments  Fraud
# 0                2          2            1  False
# 1                3          3            7   True

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'customerEmail', 'customerPhone', 'customerDevice',
#        'customerIPAddress', 'customerBillingAddress', 'No_Transactions',
#        'No_Orders', 'No_Payments', 'Fraud'],
#       dtype='object')

# %%
df['Fraud']= df['Fraud'].astype(int)

# %%
df['Fraud'].value_counts()
# Out:
# Fraud
# 0    107
# 1     61
# Name: count, dtype: int64

# %%
df.head(2)
# Out:
#    Unnamed: 0           customerEmail   customerPhone        customerDevice  \
# 0           0  josephhoward@yahoo.com    400-108-5415  yyeiaxpltf82440jnb3v
# 1           1  evansjeffery@yahoo.com  1-788-091-7546  r0jpm7xaeqqa3kr6mzum
#
#   customerIPAddress                             customerBillingAddress  \
# 0      8.129.104.40            5493 Jones Islands\nBrownside, CA 51896
# 1   219.173.211.202  356 Elizabeth Inlet Suite 120\nPort Joshuabury...
#
#    No_Transactions  No_Orders  No_Payments  Fraud
# 0                2          2            1      0
# 1                3          3            7      1

# %%
df.drop(columns=['customerEmail','customerPhone','customerBillingAddress','customerIPAddress'],inplace= True)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'customerDevice', 'No_Transactions', 'No_Orders',
#        'No_Payments', 'Fraud'],
#       dtype='object')

# %%
df['Fraud']
# Out:
# 0      0
# 1      1
# 2      0
# 3      0
# 4      1
#       ..
# 163    1
# 164    1
# 165    1
# 166    1
# 167    0
# Name: Fraud, Length: 168, dtype: int64

# %%
# convert the string to variable values
label_encoders={}
for col in df.select_dtypes(include=['object']).columns:
    le = LabelEncoder()
    df[col]= le.fit_transform(df[col])
    label_encoders[col]=le

# %%
df.fillna(df.median(),inplace=True)

# %%
x= df.drop(columns =['Fraud'])
y= df['Fraud']

# %%
X_train,X_test,Y_train,Y_test= train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = LogisticRegression(max_iter=1000, random_state=42)

# %%
model.fit(X_train,Y_train)
# Out:
# LogisticRegression(max_iter=1000, random_state=42)

# %%
Predictions = model.predict(X_test)

# %%
acc = accuracy_score(Y_test,Predictions)
clas = classification_report(Y_test, Predictions)

# %%
print("Accuracy Score : ",acc)
print("Classififcation Report : \n", clas)
# Out:
# Accuracy Score :  0.6176470588235294
# Classififcation Report :
#                precision    recall  f1-score   support
#
#            0       0.61      0.78      0.68        18
#            1       0.64      0.44      0.52        16
#
#     accuracy                           0.62        34
#    macro avg       0.62      0.61      0.60        34
# weighted avg       0.62      0.62      0.61        34
